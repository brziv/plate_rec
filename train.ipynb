# %%
# Check the annotations
# !fast-plate-ocr validate-dataset \
  --annotations-file ./dataset/train.csv \
  --plate-config-file ./configs/plate.yaml

# %%
# Visualize the stats
# !fast-plate-ocr dataset-stats \
  --annotations ./dataset/labels.csv \
  --plate-config-file ./configs/plate.yaml

# %%
# !fast-plate-ocr train \
  --model-config-file ./configs/cct_xs_v1.yaml \
  --plate-config-file ./configs/plate.yaml \
  --annotations ./dataset/train.csv \
  --val-annotations ./dataset/val.csv \
  --augmentation-path ./configs/augment.yaml \
  --epochs 50 \
  --batch-size 32 \
  --output-dir trained/ \
  --weights-path ./pretrained/cct_xs_v1.keras \
  --label-smoothing 0.0 \
  --weight-decay 0.0005 \
  --lr 0.0005

# %%
# !fast-plate-ocr valid \
  --model ./trained/2025-11-21_11-29-06/ckpt-epoch_37-acc_0.942.keras \
  --plate-config-file ./configs/plate.yaml \
  --annotations ./dataset/labels.csv
# Out:
# 2025-11-21 16:45:46.840466: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-21 16:45:46.901746: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-21 16:45:48.167240: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763743550.979924    4212 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2025-11-21 16:45:54.212746: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91300
# 8051/8051 ━━━━━━━━━━━━━━━━━━━━ 77s 9ms/step - cat_acc: 0.9952 - loss: 0.1694 - plate_acc: 0.9604 - plate_len_acc: 0.9983 - top_3_k: 0.9989

# %%
# !fast-plate-ocr export \
  --model ./trained/2025-11-21_11-29-06/ckpt-epoch_37-acc_0.942.keras \
  --plate-config-file ./configs/plate.yaml
# Out:
# 2025-11-21 17:01:37.892451: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-21 17:01:37.930379: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-21 17:01:38.937865: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763744501.274930   10134 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1763744503.206269   10134 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1763744503.206421   10134 single_machine.cc:376] Starting new session
# I0000 00:00:1763744503.207083   10134 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1763744503.452586   10134 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:From /home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/tf_loader.py:557: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2025-11-21 17:01:43 - From /home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/tf_loader.py:557: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# I0000 00:00:1763744503.485376   10134 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1763744503.485821   10134 single_machine.cc:376] Starting new session
# I0000 00:00:1763744503.486551   10134 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2025-11-21 17:01:43 - Using tensorflow=2.20.0, onnx=1.19.1, tf2onnx=1.8.4/cd55bf
# 2025-11-21 17:01:43 - Using opset <onnx, 9>
# I0000 00:00:1763744503.546647   10134 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1763744503.547655   10134 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# 2025-11-21 17:01:43 - Computed 0 values for constant folding
# 2025-11-21 17:01:43 - pass1 convert failed for name: "CCT_OCR_1/conv_stem_1/conv2d_1/convolution"
# op: "Conv2D"
# input: "CCT_OCR_1/rescaling_1/add"
# input: "CCT_OCR_1/conv_stem_1/conv2d_1/convolution/ReadVariableOp"
# attr {
#   key: "use_cudnn_on_gpu"
#   value {
#     b: true
#   }
# }
# attr {
#   key: "strides"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "padding"
#   value {
#     s: "VALID"
#   }
# }
# attr {
#   key: "explicit_paddings"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "dilations"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "data_format"
#   value {
#     s: "NHWC"
#   }
# }
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# , ex=Could not infer attribute `explicit_paddings` type from empty iterator
# Traceback (most recent call last):
#   File "/home/brziv/miniconda3/envs/plate/bin/fast-plate-ocr", line 7, in <module>
#     sys.exit(main_cli())
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/click/core.py", line 1485, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/click/core.py", line 1406, in main
#     rv = self.invoke(ctx)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/click/core.py", line 1873, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/click/core.py", line 1269, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/click/core.py", line 824, in invoke
#     return callback(*args, **kwargs)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/fast_plate_ocr/cli/export.py", line 370, in export
#     export_onnx(
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/fast_plate_ocr/cli/utils.py", line 112, in wrapper
#     return fn(*args, **kwargs)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/fast_plate_ocr/cli/export.py", line 139, in export_onnx
#     export_model.export(tmp.name, format="onnx", verbose=False, input_signature=spec)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/keras/src/models/model.py", line 651, in export
#     export_onnx(
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/keras/src/export/onnx.py", line 98, in export_onnx
#     tf2onnx.convert.from_function(
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/convert.py", line 387, in from_function
#     model_proto, external_tensor_storage = _convert_common(
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/convert.py", line 153, in _convert_common
#     g = process_tf_graph(tf_graph, const_node_values=const_node_values, **kwargs)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/tfonnx.py", line 507, in process_tf_graph
#     tensorflow_to_onnx(tf_graph, shape_override, const_node_values, ignore_default, use_default)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/tf_utils.py", line 460, in tensorflow_to_onnx
#     return tflist_to_onnx(graph, shape_override, const_node_values, ignore_default, use_default)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/tf2onnx/tf_utils.py", line 447, in tflist_to_onnx
#     onnx_node = helper.make_node(node_type, input_names, output_names, name=node.name, **attr)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/onnx/helper.py", line 170, in make_node
#     node.attribute.extend(
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/onnx/helper.py", line 171, in <genexpr>
#     make_attribute(key, value)
#   File "/home/brziv/miniconda3/envs/plate/lib/python3.10/site-packages/onnx/helper.py", line 977, in make_attribute
#     raise ValueError(
# ValueError: Could not infer attribute `explicit_paddings` type from empty iterator
